# %%
# %run wise.ipynb
# %run paypal.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80389 entries, 0 to 80388
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  80389 non-null  object
#  1   Time                  80389 non-null  object
#  2   TimeZone              80389 non-null  object
#  3   Name                  77619 non-null  object
#  4   Type                  80389 non-null  object
#  5   Status                80389 non-null  object
#  6   Currency              80389 non-null  object
#  7   Gross                 80389 non-null  float64
#  8   Fee                   80389 non-null  float64
#  9   Net                   80389 non-null  float64
#  10  From Email Address    77336 non-null  object
#  11  To Email Address      77738 non-null  object
#  12  Transaction ID        80389 non-null  object
#  13  Address Status        75893 non-null  object
# ...

# %%
df_platform.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 845230 entries, 0 to 845229
# Data columns (total 74 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   id                                    845230 non-null  object
#  1   uuid                                  845230 non-null  object
#  2   kind                                  845230 non-null  object
#  3   payoutMethod                          0 non-null       float64
#  4   giftCardEmitterAccount                0 non-null       float64
#  5   group                                 845230 non-null  object
#  6   type                                  845230 non-null  object
#  7   description                           845230 non-null  object
#  8   createdAt                             845230 non-null  datetime64[ns]
#  9   merchantId                            197242 non-null  object
# ...

# %%
df_platform_left = df_platform[~df_platform['id'].isin(df_platform_wise['id']) & ~df_platform['id'].isin(df_platform_paypal['id'])]

# %%
df_platform_left.value_counts('kind')
# Out:
# kind
# HOST_FEE                         385894
# HOST_FEE_SHARE                   192946
# CONTRIBUTION                     135447
# HOST_FEE_SHARE_DEBT               61479
# ADDED_FUNDS                        2616
# EXPENSE                            2606
# PAYMENT_PROCESSOR_COVER             728
# BALANCE_TRANSFER                    116
# PAYMENT_PROCESSOR_DISPUTE_FEE        18
# PREPAID_PAYMENT_METHOD               13
# PLATFORM_TIP_DEBT                    11
# Name: count, dtype: int64
